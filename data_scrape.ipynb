# %%
# !pip install soccerdata
# Out:
# Requirement already satisfied: soccerdata in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (1.8.8)
# Requirement already satisfied: html5lib<2.0.0,>=1.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from soccerdata) (1.1)
# Requirement already satisfied: lxml>=5.0.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from soccerdata) (6.0.2)
# Requirement already satisfied: pandas!=2.1.0,<3.0.0,>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from soccerdata) (2.2.3)
# Requirement already satisfied: rich<15.0.0,>=14.0.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from soccerdata) (14.2.0)
# Requirement already satisfied: seleniumbase<5.0.0,>=4.38.2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from soccerdata) (4.38.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.67.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from soccerdata) (4.67.1)
# Requirement already satisfied: unidecode<2.0.0,>=1.4.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from soccerdata) (1.4.0)
# Requirement already satisfied: urllib3<2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from soccerdata) (1.26.20)
# Requirement already satisfied: wrapper-tls-requests<2.0.0,>=1.1.4 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from soccerdata) (1.2.4)
# Requirement already satisfied: six>=1.9 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from html5lib<2.0.0,>=1.1->soccerdata) (1.17.0)
# Requirement already satisfied: webencodings in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from html5lib<2.0.0,>=1.1->soccerdata) (0.5.1)
# Requirement already satisfied: numpy>=1.26.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pandas!=2.1.0,<3.0.0,>=2.0.0->soccerdata) (2.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pandas!=2.1.0,<3.0.0,>=2.0.0->soccerdata) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pandas!=2.1.0,<3.0.0,>=2.0.0->soccerdata) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pandas!=2.1.0,<3.0.0,>=2.0.0->soccerdata) (2024.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from rich<15.0.0,>=14.0.0->soccerdata) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from rich<15.0.0,>=14.0.0->soccerdata) (2.19.2)
# Requirement already satisfied: pip>=25.1.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from seleniumbase<5.0.0,>=4.38.2->soccerdata) (26.0.1)
# Requirement already satisfied: packaging>=25.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from seleniumbase<5.0.0,>=4.38.2->soccerdata) (26.0)
# Requirement already satisfied: setuptools>=80.8.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from seleniumbase<5.0.0,>=4.38.2->soccerdata) (81.0.0)
# Requirement already satisfied: wheel>=0.45.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from seleniumbase<5.0.0,>=4.38.2->soccerdata) (0.45.1)
# Requirement already satisfied: attrs>=25.3.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from seleniumbase<5.0.0,>=4.38.2->soccerdata) (25.4.0)
# Requirement already satisfied: certifi>=2025.4.26 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from seleniumbase<5.0.0,>=4.38.2->soccerdata) (2026.1.4)
# Requirement already satisfied: exceptiongroup>=1.3.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from seleniumbase<5.0.0,>=4.38.2->soccerdata) (1.3.1)
# Requirement already satisfied: websockets>=15.0.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from seleniumbase<5.0.0,>=4.38.2->soccerdata) (16.0)
# Requirement already satisfied: filelock>=3.18.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from seleniumbase<5.0.0,>=4.38.2->soccerdata) (3.18.0)
# Requirement already satisfied: fasteners>=0.19 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from seleniumbase<5.0.0,>=4.38.2->soccerdata) (0.20)
# Requirement already satisfied: mycdp>=1.2.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from seleniumbase<5.0.0,>=4.38.2->soccerdata) (1.3.2)
# Requirement already satisfied: pynose>=1.5.4 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from seleniumbase<5.0.0,>=4.38.2->soccerdata) (1.5.5)
# Requirement already satisfied: platformdirs>=4.3.8 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from seleniumbase<5.0.0,>=4.38.2->soccerdata) (4.5.1)
# Requirement already satisfied: typing-extensions>=4.13.2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from seleniumbase<5.0.0,>=4.38.2->soccerdata) (4.15.0)
# Requirement already satisfied: sbvirtualdisplay>=1.4.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from seleniumbase<5.0.0,>=4.38.2->soccerdata) (1.4.0)
# Requirement already satisfied: MarkupSafe>=3.0.2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from seleniumbase<5.0.0,>=4.38.2->soccerdata) (3.0.2)
# Requirement already satisfied: Jinja2>=3.1.6 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from seleniumbase<5.0.0,>=4.38.2->soccerdata) (3.1.6)
# Requirement already satisfied: parse>=1.20.2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from seleniumbase<5.0.0,>=4.38.2->soccerdata) (1.21.0)
# Requirement already satisfied: parse-type>=0.6.4 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from seleniumbase<5.0.0,>=4.38.2->soccerdata) (0.6.6)
# Requirement already satisfied: colorama>=0.4.6 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from seleniumbase<5.0.0,>=4.38.2->soccerdata) (0.4.6)
# Requirement already satisfied: pyyaml>=6.0.2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from seleniumbase<5.0.0,>=4.38.2->soccerdata) (6.0.2)
# Requirement already satisfied: tabcompleter>=1.4.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from seleniumbase<5.0.0,>=4.38.2->soccerdata) (1.4.0)
# Requirement already satisfied: pdbp>=1.7.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from seleniumbase<5.0.0,>=4.38.2->soccerdata) (1.8.2)
# Requirement already satisfied: idna==3.10 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from seleniumbase<5.0.0,>=4.38.2->soccerdata) (3.10)
# Requirement already satisfied: chardet==5.2.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from seleniumbase<5.0.0,>=4.38.2->soccerdata) (5.2.0)
# Requirement already satisfied: charset-normalizer<4,>=3.4.2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from seleniumbase<5.0.0,>=4.38.2->soccerdata) (3.4.4)
# Requirement already satisfied: requests==2.32.3 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from seleniumbase<5.0.0,>=4.38.2->soccerdata) (2.32.3)
# Requirement already satisfied: sniffio==1.3.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from seleniumbase<5.0.0,>=4.38.2->soccerdata) (1.3.1)
# Requirement already satisfied: h11==0.16.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from seleniumbase<5.0.0,>=4.38.2->soccerdata) (0.16.0)
# Requirement already satisfied: outcome==1.3.0.post0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from seleniumbase<5.0.0,>=4.38.2->soccerdata) (1.3.0.post0)
# Requirement already satisfied: trio==0.30.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from seleniumbase<5.0.0,>=4.38.2->soccerdata) (0.30.0)
# Requirement already satisfied: trio-websocket==0.12.2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from seleniumbase<5.0.0,>=4.38.2->soccerdata) (0.12.2)
# Requirement already satisfied: wsproto==1.2.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from seleniumbase<5.0.0,>=4.38.2->soccerdata) (1.2.0)
# Requirement already satisfied: websocket-client==1.8.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from seleniumbase<5.0.0,>=4.38.2->soccerdata) (1.8.0)
# Requirement already satisfied: selenium==4.32.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from seleniumbase<5.0.0,>=4.38.2->soccerdata) (4.32.0)
# Requirement already satisfied: cssselect==1.3.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from seleniumbase<5.0.0,>=4.38.2->soccerdata) (1.3.0)
# Requirement already satisfied: sortedcontainers==2.4.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from seleniumbase<5.0.0,>=4.38.2->soccerdata) (2.4.0)
# Requirement already satisfied: execnet==2.1.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from seleniumbase<5.0.0,>=4.38.2->soccerdata) (2.1.1)
# Requirement already satisfied: iniconfig==2.1.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from seleniumbase<5.0.0,>=4.38.2->soccerdata) (2.1.0)
# Requirement already satisfied: pluggy==1.6.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from seleniumbase<5.0.0,>=4.38.2->soccerdata) (1.6.0)
# Requirement already satisfied: pytest==8.3.5 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from seleniumbase<5.0.0,>=4.38.2->soccerdata) (8.3.5)
# Requirement already satisfied: pytest-html==4.0.2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from seleniumbase<5.0.0,>=4.38.2->soccerdata) (4.0.2)
# Requirement already satisfied: pytest-metadata==3.1.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from seleniumbase<5.0.0,>=4.38.2->soccerdata) (3.1.1)
# Requirement already satisfied: pytest-ordering==0.6 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from seleniumbase<5.0.0,>=4.38.2->soccerdata) (0.6)
# Requirement already satisfied: pytest-rerunfailures==15.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from seleniumbase<5.0.0,>=4.38.2->soccerdata) (15.1)
# Requirement already satisfied: pytest-xdist==3.6.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from seleniumbase<5.0.0,>=4.38.2->soccerdata) (3.6.1)
# Requirement already satisfied: parameterized==0.9.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from seleniumbase<5.0.0,>=4.38.2->soccerdata) (0.9.0)
# Requirement already satisfied: behave==1.2.6 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from seleniumbase<5.0.0,>=4.38.2->soccerdata) (1.2.6)
# Requirement already satisfied: soupsieve==2.7 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from seleniumbase<5.0.0,>=4.38.2->soccerdata) (2.7)
# Requirement already satisfied: beautifulsoup4==4.13.4 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from seleniumbase<5.0.0,>=4.38.2->soccerdata) (4.13.4)
# Requirement already satisfied: pyotp==2.9.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from seleniumbase<5.0.0,>=4.38.2->soccerdata) (2.9.0)
# Requirement already satisfied: mdurl==0.1.2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from seleniumbase<5.0.0,>=4.38.2->soccerdata) (0.1.2)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from urllib3[socks]<3,>=1.26->selenium==4.32.0->seleniumbase<5.0.0,>=4.38.2->soccerdata) (1.7.1)
# Requirement already satisfied: orjson in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from wrapper-tls-requests<2.0.0,>=1.1.4->soccerdata) (3.11.7)

# %%
import soccerdata as sd

# get EPL data for a season
fbref = sd.FBref(leagues="ENG-Premier League", seasons=["2015-16","2016-17", "2017-18", "2018-19","2019-20","2020-21","2021-22","2022-23","2023-24","2024-25"])

# league match stats for all those seasons
df_matches = fbref.read_schedule()
print(df_matches.head())

# team statistics
df_team_stats = fbref.read_team_stats()
print(df_team_stats.head())
# Out:
# [02/06/26 20:49:50] INFO     No custom team name replacements found. You can configure these in       ]8;id=95615;file:///Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/soccerdata/_config.py\_config.py]8;;\:]8;id=454916;file:///Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/soccerdata/_config.py#92\92]8;;\
#                              /Users/varsha/soccerdata/config/teamname_replacements.json.
#                     INFO     No custom league dict found. You can configure additional leagues in    ]8;id=61175;file:///Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/soccerdata/_config.py\_config.py]8;;\:]8;id=129473;file:///Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/soccerdata/_config.py#198\198]8;;\
#                              /Users/varsha/soccerdata/config/league_dict.json.
#                     INFO     Saving cached data to /Users/varsha/soccerdata/data/FBref               ]8;id=335644;file:///Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/soccerdata/_common.py\_common.py]8;;\:]8;id=163564;file:///Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/soccerdata/_common.py#249\249]8;;\
# [2026-02-06 20:49:50] INFO     TLSLibrary:load:435 - Downloading required library version v1.13.1...
#                     INFO     Downloading required library version v1.13.1...                       ]8;id=136549;file:///Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/tls_requests/models/libraries.py\libraries.py]8;;\:]8;id=863968;file:///Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/tls_requests/models/libraries.py#435\435]8;;\
# [2026-02-06 20:49:50] INFO     TLSLibrary:download:314 - System Info - Platform: darwin, Machine: arm64, File Ext : dylib.
#                     INFO     System Info - Platform: darwin, Machine: arm64, File Ext : dylib.     ]8;id=710409;file:///Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/tls_requests/models/libraries.py\libraries.py]8;;\:]8;id=239474;file:///Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/tls_requests/models/libraries.py#314\314]8;;\
# [2026-02-06 20:49:51] INFO     TLSLibrary:export_config:193 - Saved release config to /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/tls_requests/bin/release.json
# [02/06/26 20:49:51] INFO     Saved release config to                                               ]8;id=225320;file:///Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/tls_requests/models/libraries.py\libraries.py]8;;\:]8;id=526485;file:///Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/tls_requests/models/libraries.py#193\193]8;;\
#                              /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/sit
#                              e-packages/tls_requests/bin/release.json
# [2026-02-06 20:49:51] INFO     TLSLibrary:fetch_api:239 - Fetched release data from GitHub API.
#                     INFO     Fetched release data from GitHub API.                                 ]8;id=564306;file:///Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/tls_requests/models/libraries.py\libraries.py]8;;\:]8;id=841617;file:///Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/tls_requests/models/libraries.py#239\239]8;;\
# [2026-02-06 20:49:51] INFO     TLSLibrary:download:328 - Trying to download library from: https://github.com/bogdanfinn/tls-client/releases/download/v1.13.1/tls-client-darwin-arm64-1.13.1.dylib
#                     INFO     Trying to download library from:                                      ]8;id=700835;file:///Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/tls_requests/models/libraries.py\libraries.py]8;;\:]8;id=22937;file:///Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/tls_requests/models/libraries.py#328\328]8;;\
#                              https://github.com/bogdanfinn/tls-client/releases/download/v1.13.1/tl
#                              s-client-darwin-arm64-1.13.1.dylib
# Downloading tls-client-darwin-arm64-1.13.1.dylib: [==================================================] 100.0%
# [2026-02-06 20:49:52] INFO     TLSLibrary:_load_library:397 - Successfully loaded TLS library: /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/tls_requests/bin/tls-client-darwin-arm64-1.13.1.dylib
# [02/06/26 20:49:52] INFO     Successfully loaded TLS library:                                      ]8;id=963807;file:///Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/tls_requests/models/libraries.py\libraries.py]8;;\:]8;id=291232;file:///Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/tls_requests/models/libraries.py#397\397]8;;\
#                              /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/sit
#                              e-packages/tls_requests/bin/tls-client-darwin-arm64-1.13.1.dylib
# [02/06/26 20:49:59] ERROR    Error while scraping https://fbref.com/en/comps/. Retrying... (attempt  ]8;id=496928;file:///Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/soccerdata/_common.py\_common.py]8;;\:]8;id=238759;file:///Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/soccerdata/_common.py#526\526]8;;\
#                              1 of 5).
#                              Traceback (most recent call last):
#                                File
#                              "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site
#                              -packages/soccerdata/_common.py", line 506, in _download_and_save
#                                  response.raise_for_status()
#                                  ~~~~~~~~~~~~~~~~~~~~~~~~~^^
#                                File
#                              "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site
#                              -packages/tls_requests/models/response.py", line 207, in
#                              raise_for_status
#                                  raise HTTPError(
#                                  ...<6 lines>...
#                                  )
#                              tls_requests.exceptions.HTTPError: 403 Client Error: Forbidden for url:
#                              https://fbref.com/en/comps/
# [02/06/26 20:50:07] ERROR    Error while scraping https://fbref.com/en/comps/. Retrying... (attempt  ]8;id=741602;file:///Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/soccerdata/_common.py\_common.py]8;;\:]8;id=448358;file:///Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/soccerdata/_common.py#526\526]8;;\
#                              2 of 5).
#                              Traceback (most recent call last):
#                                File
#                              "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site
#                              -packages/soccerdata/_common.py", line 506, in _download_and_save
#                                  response.raise_for_status()
#                                  ~~~~~~~~~~~~~~~~~~~~~~~~~^^
#                                File
#                              "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site
#                              -packages/tls_requests/models/response.py", line 207, in
#                              raise_for_status
#                                  raise HTTPError(
#                                  ...<6 lines>...
#                                  )
#                              tls_requests.exceptions.HTTPError: 403 Client Error: Forbidden for url:
#                              https://fbref.com/en/comps/
# [02/06/26 20:50:14] ERROR    Error while scraping https://fbref.com/en/comps/. Retrying... (attempt  ]8;id=235295;file:///Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/soccerdata/_common.py\_common.py]8;;\:]8;id=631748;file:///Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/soccerdata/_common.py#526\526]8;;\
#                              3 of 5).
#                              Traceback (most recent call last):
#                                File
#                              "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site
#                              -packages/soccerdata/_common.py", line 506, in _download_and_save
#                                  response.raise_for_status()
#                                  ~~~~~~~~~~~~~~~~~~~~~~~~~^^
#                                File
#                              "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site
#                              -packages/tls_requests/models/response.py", line 207, in
#                              raise_for_status
#                                  raise HTTPError(
#                                  ...<6 lines>...
#                                  )
#                              tls_requests.exceptions.HTTPError: 403 Client Error: Forbidden for url:
#                              https://fbref.com/en/comps/
# [02/06/26 20:50:22] ERROR    Error while scraping https://fbref.com/en/comps/. Retrying... (attempt  ]8;id=537350;file:///Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/soccerdata/_common.py\_common.py]8;;\:]8;id=503249;file:///Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/soccerdata/_common.py#526\526]8;;\
#                              4 of 5).
#                              Traceback (most recent call last):
#                                File
#                              "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site
#                              -packages/soccerdata/_common.py", line 506, in _download_and_save
#                                  response.raise_for_status()
#                                  ~~~~~~~~~~~~~~~~~~~~~~~~~^^
#                                File
#                              "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site
#                              -packages/tls_requests/models/response.py", line 207, in
#                              raise_for_status
#                                  raise HTTPError(
#                                  ...<6 lines>...
#                                  )
#                              tls_requests.exceptions.HTTPError: 403 Client Error: Forbidden for url:
#                              https://fbref.com/en/comps/
# [02/06/26 20:50:29] ERROR    Error while scraping https://fbref.com/en/comps/. Retrying... (attempt  ]8;id=632637;file:///Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/soccerdata/_common.py\_common.py]8;;\:]8;id=799383;file:///Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/soccerdata/_common.py#526\526]8;;\
#                              5 of 5).
#                              Traceback (most recent call last):
#                                File
#                              "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site
#                              -packages/soccerdata/_common.py", line 506, in _download_and_save
#                                  response.raise_for_status()
#                                  ~~~~~~~~~~~~~~~~~~~~~~~~~^^
#                                File
#                              "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site
#                              -packages/tls_requests/models/response.py", line 207, in
#                              raise_for_status
#                                  raise HTTPError(
#                                  ...<6 lines>...
#                                  )
#                              tls_requests.exceptions.HTTPError: 403 Client Error: Forbidden for url:
#                              https://fbref.com/en/comps/
# ---------------------------------------------------------------------------
# ConnectionError                           Traceback (most recent call last)
# Cell In[2], line 7
#       4 fbref = sd.FBref(leagues="ENG-Premier League", seasons=["2015-16","2016-17", "2017-18", "2018-19","2019-20","2020-21","2021-22","2022-23","2023-24","2024-25"])
#       6 # league match stats for all those seasons
# ----> 7 df_matches = fbref.read_schedule()
#       8 print(df_matches.head())
#      10 # team statistics
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/soccerdata/fbref.py:660, in FBref.read_schedule(self, force_cache)
#     647 """Retrieve the game schedule for the selected leagues and seasons.
#     648
#     649 Parameters
#    (...)    657 pd.DataFrame
#     658 """
#     659 # get league IDs
# --> 660 seasons = self.read_seasons(split_up_big5=True)
#     662 # collect teams
#     663 schedule = []
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/soccerdata/fbref.py:193, in FBref.read_seasons(self, split_up_big5)
#     180 """Retrieve the selected seasons for the selected leagues.
#     181
#     182 Parameters
#    (...)    190 pd.DataFrame
#     191 """
#     192 filemask = "seasons_{}.html"
# --> 193 df_leagues = self.read_leagues(split_up_big5)
#     195 seasons = []
#     196 for lkey, league in df_leagues.iterrows():
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/soccerdata/fbref.py:149, in FBref.read_leagues(self, split_up_big5)
#     147 url = f"{FBREF_API}/en/comps/"
#     148 filepath = self.data_dir / "leagues.html"
# --> 149 reader = self.get(url, filepath)
#     151 # extract league links
#     152 dfs = []
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/soccerdata/_common.py:292, in BaseReader.get(self, url, filepath, max_age, no_cache, var)
#     290 if no_cache or self.no_cache or not is_cached:
#     291     logger.debug("Scraping %s", url)
# --> 292     return self._download_and_save(url, filepath, var)
#     293 logger.debug("Retrieving %s from cache", url)
#     294 if filepath is None:
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/soccerdata/_common.py:534, in BaseRequestsReader._download_and_save(self, url, filepath, var)
#     531         self._session = self._init_session()
#     532         continue
# --> 534 raise ConnectionError(f"Could not download {url}.")
#
# ConnectionError: Could not download https://fbref.com/en/comps/.
