# %%
import pandas as pd

# %%
# Load all 25 EPL datasets
datasets = {}
for i in range(25):
    year_start = str(i).zfill(2)
    year_end = str(i + 1).zfill(2)
    filename = f'../data/epl/EPL_{year_start}{year_end}.csv'
    df_name = f'df_{year_start}{year_end}'
    try:
        datasets[df_name] = pd.read_csv(filename, on_bad_lines='skip', engine='python')
        globals()[df_name] = datasets[df_name]
    except Exception as e:
        print(f"Error loading {filename}: {e}")
# Out:
# Error loading ../data/epl/EPL_0405.csv: 'utf-8' codec can't decode byte 0xa0 in position 1886: invalid start byte

# %%
# Select only required columns
required_columns = ['Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HS', 'AS', 'HST', 'AST', 'HC', 'AC', 'HY', 'AY', 'HR', 'AR']

for df_name in datasets:
    datasets[df_name] = datasets[df_name][required_columns]
    globals()[df_name] = datasets[df_name]

# Verify columns
print(df_0506.columns.tolist()) # Select only required columns
required_columns = ['Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HS', 'AS', 'HST', 'AST', 'HC', 'AC', 'HY', 'AY', 'HR', 'AR']

for df_name in datasets:
    datasets[df_name] = datasets[df_name][required_columns]
    globals()[df_name] = datasets[df_name]
# Out:
# ['Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HS', 'AS', 'HST', 'AST', 'HC', 'AC', 'HY', 'AY', 'HR', 'AR']

# %%
liverpool_matches = df_1920[(df_1920['HomeTeam'] == 'Liverpool') | (df_1920['AwayTeam'] == 'Liverpool')]
print(liverpool_matches)
# Out:
#            Date          HomeTeam          AwayTeam  FTHG  FTAG FTR  HS  AS  \
# 0    09/08/2019         Liverpool           Norwich     4     1   H  15  12
# 15   17/08/2019       Southampton         Liverpool     1     2   A  14  15
# 26   24/08/2019         Liverpool           Arsenal     3     1   H  25   9
# 37   31/08/2019           Burnley         Liverpool     0     3   A   7  15
# 40   14/09/2019         Liverpool         Newcastle     3     1   H  21   8
# 59   22/09/2019           Chelsea         Liverpool     1     2   A  13   6
# 60   28/09/2019  Sheffield United         Liverpool     0     1   A  12  16
# 72   05/10/2019         Liverpool         Leicester     2     1   H  18   2
# 88   20/10/2019        Man United         Liverpool     1     1   D   7  10
# 98   27/10/2019         Liverpool         Tottenham     2     1   H  21  11
# 102  02/11/2019       Aston Villa         Liverpool     1     2   A   5  25
# ...

# %%
# Concatenate all datasets into a single dataframe
df_combined = pd.concat(datasets.values(), ignore_index=True)

print(f"Combined dataset shape: {df_combined.shape}")
df_combined
# Out:
# Combined dataset shape: (9076, 16)
#             Date       HomeTeam       AwayTeam  FTHG  FTAG FTR    HS    AS  \
# 0       19/08/00       Charlton       Man City   4.0   0.0   H  17.0   8.0
# 1       19/08/00        Chelsea       West Ham   4.0   2.0   H  17.0  12.0
# 2       19/08/00       Coventry  Middlesbrough   1.0   3.0   A   6.0  16.0
# 3       19/08/00          Derby    Southampton   2.0   2.0   D   6.0  13.0
# 4       19/08/00          Leeds        Everton   2.0   0.0   H  17.0  12.0
# ...          ...            ...            ...   ...   ...  ..   ...   ...
# 9071  25/05/2025      Newcastle        Everton   0.0   1.0   A  17.0  14.0
# 9072  25/05/2025  Nott'm Forest        Chelsea   0.0   1.0   A  10.0   6.0
# 9073  25/05/2025    Southampton        Arsenal   1.0   2.0   A   7.0  23.0
# 9074  25/05/2025      Tottenham       Brighton   1.0   4.0   A   4.0  23.0
# 9075  25/05/2025         Wolves      Brentford   1.0   1.0   D  18.0  13.0
#
# ...

# %%
# remove rows with null values
df_cleaned = df_combined.dropna()
df_cleaned
# Out:
#             Date       HomeTeam       AwayTeam  FTHG  FTAG FTR    HS    AS  \
# 0       19/08/00       Charlton       Man City   4.0   0.0   H  17.0   8.0
# 1       19/08/00        Chelsea       West Ham   4.0   2.0   H  17.0  12.0
# 2       19/08/00       Coventry  Middlesbrough   1.0   3.0   A   6.0  16.0
# 3       19/08/00          Derby    Southampton   2.0   2.0   D   6.0  13.0
# 4       19/08/00          Leeds        Everton   2.0   0.0   H  17.0  12.0
# ...          ...            ...            ...   ...   ...  ..   ...   ...
# 9071  25/05/2025      Newcastle        Everton   0.0   1.0   A  17.0  14.0
# 9072  25/05/2025  Nott'm Forest        Chelsea   0.0   1.0   A  10.0   6.0
# 9073  25/05/2025    Southampton        Arsenal   1.0   2.0   A   7.0  23.0
# 9074  25/05/2025      Tottenham       Brighton   1.0   4.0   A   4.0  23.0
# 9075  25/05/2025         Wolves      Brentford   1.0   1.0   D  18.0  13.0
#
#        HST  AST    HC    AC   HY   AY   HR   AR
# ...

# %%
change_row_names = ['date', 'home_team', 'away_team', 'full_time_home_goals', 'full_time_away_goals', 
                    'full_time_result', 'home_shots', 'away_shots', 'home_shots_on_target', 'away_shots_on_target',
                    'home_corners', 'away_corners', 'home_yellow_cards', 'away_yellow_cards', 'home_red_cards',
                    'away_red_cards']
df_cleaned.columns = change_row_names
df_cleaned
# Out:
#             date      home_team      away_team  full_time_home_goals  \
# 0       19/08/00       Charlton       Man City                   4.0
# 1       19/08/00        Chelsea       West Ham                   4.0
# 2       19/08/00       Coventry  Middlesbrough                   1.0
# 3       19/08/00          Derby    Southampton                   2.0
# 4       19/08/00          Leeds        Everton                   2.0
# ...          ...            ...            ...                   ...
# 9071  25/05/2025      Newcastle        Everton                   0.0
# 9072  25/05/2025  Nott'm Forest        Chelsea                   0.0
# 9073  25/05/2025    Southampton        Arsenal                   1.0
# 9074  25/05/2025      Tottenham       Brighton                   1.0
# 9075  25/05/2025         Wolves      Brentford                   1.0
#
#       full_time_away_goals full_time_result  home_shots  away_shots  \
# 0                      0.0                H        17.0         8.0
# ...

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9075 entries, 0 to 9075
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   date                  9075 non-null   object
#  1   home_team             9075 non-null   object
#  2   away_team             9075 non-null   object
#  3   full_time_home_goals  9075 non-null   float64
#  4   full_time_away_goals  9075 non-null   float64
#  5   full_time_result      9075 non-null   object
#  6   home_shots            9075 non-null   float64
#  7   away_shots            9075 non-null   float64
#  8   home_shots_on_target  9075 non-null   float64
#  9   away_shots_on_target  9075 non-null   float64
#  10  home_corners          9075 non-null   float64
#  11  away_corners          9075 non-null   float64
#  12  home_yellow_cards     9075 non-null   float64
#  13  away_yellow_cards     9075 non-null   float64
# ...
